# %%
import pandas as pd
import numpy as np

# %%
UDESS_FILE = '~/Documents/PRN/Python/pubmed_result.txt'
pubmed = pd.read_csv(UDESS_FILE, sep='\t')

# %%
pubmed.head()
# Out:
#   1. Nippon Ganka Gakkai Zasshi. 2014 Nov;118(11):943-52.
# 0  [Impact of anti-VEGF therapy on the cellular m...
# 1                                     angiogenesis].
# 2                              [Article in Japanese]
# 3                                           Nakao S.
# 4  Various large-scale studies show the efficacy ...

# %%
pubmed
# Out:
#     1. Nippon Ganka Gakkai Zasshi. 2014 Nov;118(11):943-52.
# 0    [Impact of anti-VEGF therapy on the cellular m...
# 1                                       angiogenesis].
# 2                                [Article in Japanese]
# 3                                             Nakao S.
# 4    Various large-scale studies show the efficacy ...
# 5    factor (VEGF) therapy in treatment of retinal ...
# 6    is expected that this therapeutic strategy wil...
# 7    retinal vascular diseases including diabetic r...
# 8    occlusion. Leukocyte infiltration is an import...
# 9    angiogenesis in inflammatory diseases. Various...
# 10   leukocytes are a prerequisite for retinal angi...
# 11   retinopathy. Furthermore, the fibrovascular me...
# 12   consists of stromal components (extracellular ...
# 13   leukocytes) supported by angiogenesis (endothe...
# 14   activity of proliferative diabetic retinopathy...
# 15   by the angiogenesis-assisted FVM microenvironm...
# ...
